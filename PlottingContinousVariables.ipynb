# %% [markdown]
# ## Intro to Plott Data with Python
# Matplot lib is the most common plotting utlity for python.  In gereneral, plotting with python works very well from small data, but doesn't scale much beyond a few thousand rows.
# Most plotting methofd in python are actually using matplot lib under the hood
#
# Data to be used the sklearn boston housing data
# https://scikit-learn.org/stable/datasets/index.html#boston-dataset

# %% [markdown]
# #### Plotting Methods for Continous Variables
# + Correlation Plots
# + Scatter Plots
# + Histograms / Density Plots

# %% [markdown]
# ### Correlation Plots
# Best used with continoud variables, to find positive and negative relationships, especially with colots of continous variables
# + generall guide lindes (use sort variable names, long ones get cut off or otherwise difficult to read)
# + Use Cool Warm color palet where blue is negative, and red is positive (white shows little correlation)
# + Include correlation numbers on blocks,
# + becomes very difficult to read, past about 10 variables
# + leverage self organization if possible

# %%
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
b = load_boston()

feature_names = b.feature_names
df = pd.DataFrame(b.data, columns=feature_names)
df['price'] = b.target
df.head(2)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
#
#    PTRATIO      B  LSTAT  price
# 0     15.3  396.9   4.98   24.0
# 1     17.8  396.9   9.14   21.6

# %%
## Correlation Plots
corr = df.corr()  ## create a correlation matrix
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_d8387074_f36c_11e9_a784_f834415cd352row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row0_col1 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row0_col2 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row0_col3 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row0_col4 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row0_col5 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row0_col6 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row0_col7 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row0_col8 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row0_col9 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row0_col10 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row0_col11 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row0_col12 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row0_col13 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row1_col0 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row1_col2 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row1_col3 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row1_col4 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row1_col5 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row1_col6 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row1_col7 {
#             background-color:  #ec7f63;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row1_col8 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row1_col9 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row1_col10 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row1_col11 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row1_col12 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row1_col13 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row2_col0 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row2_col1 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row2_col3 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row2_col4 {
#             background-color:  #e0654f;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row2_col5 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row2_col6 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row2_col7 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row2_col8 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row2_col9 {
#             background-color:  #ea7b60;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row2_col10 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row2_col11 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row2_col12 {
#             background-color:  #f29072;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row2_col13 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row3_col0 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row3_col1 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row3_col2 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row3_col4 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row3_col5 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row3_col6 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row3_col7 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row3_col8 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row3_col9 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row3_col10 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row3_col11 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row3_col12 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row3_col13 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row4_col0 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row4_col1 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row4_col2 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_d8387074_f36c_11e9_a784_f834415cd352row4_col3 {
#             background-color:  #779af7;
#             colo

# %% [markdown]
# Conclusions
# + LSTAT % lower status of the population negatively correlated to price
# + RM average number of rooms per dwelling is positively correlated with price.

# %% [markdown]
# ## Scatter Plots
# Use Scatter plots to describe relationshio between two continous variables
# + Works well when there is actually a linear relationship
# + Outliers can negatively effect plot
# + With large data sets, plot only a sample
# + Handels very large col names, since the can be put parallel with the x and y axis
# + Use Colors, and Size to add aditional continous dimensions
# + Use shape or color to and catagorical Dimensions
# + Use color maps to control the pallet (cmap)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = df.TAX
x_lab = 'TAX full-value property-tax rate per $10,000'
y_lab = 'PTRATIO pupil-teacher ratio by town'
y = df.PTRATIO
s = df.price ## scale (point size)
c = df.price  ## color

## Plotting script
plt.scatter(x, y, s, c, cmap ='coolwarm')
plt.xlabel(x_lab)
plt.ylabel(y_lab)
plt.title('Tax and Pupil Teacher Ration, colored by Price')
plt.show()

# %% [markdown]
# Concluesions
# + Expensive housing tends to cluster where  pupile to teacher rates are low, and property tax is low

# %% [markdown]
# #### Density Plots
# Denisty plots are used to show where the data is centered and generally only look at one or two variables at a time

# %%
## Pandas has a Histogram method built in
## matplot lib methods can be used to add things like titles
plt.title('Histogram of Price')
plt.show()

# %% [markdown]
# Conclusion,
# most prices are centered around the 20s, with a few outliers at 50

# %% [markdown]
# ### 3 D Scatter Ploting
# + Often very difficult to interperate, but sometimes is very appropriate (if x, y are lat and lon for example)

# %%
from mpl_toolkits.mplot3d import Axes3D


xs = df.TAX
x_lab = 'TAX full-value property-tax rate per $10,000'
y_lab = 'PTRATIO pupil-teacher ratio by town'
ys = df.PTRATIO
s = df.price ## scale (point size)
c = df.price  ## color
zs = df.price

## Plotting script

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(xs = xs, ys=ys, zs=zs, zdir='z', s=s,  c = c, cmap ='coolwarm')

ax.set_xlabel('Tax')
ax.set_ylabel('PTRATIO')
ax.set_zlabel('PRICE')
ax.set_title('3D Plotting is often Difficult to Understand')
plt.show()

# %%
## Can be COmbined with Predictive Models
from sklearn.tree import DecisionTreeRegressor
X = df[['TAX', 'PTRATIO']].values
y = df['price']
model = DecisionTreeRegressor().fit(X, y)

# %%
h = 1

x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# here "model" is your model's prediction (classification) function
Z = model.predict(np.c_[xx.ravel(), yy.ravel()]) 

# Put the result into a color plot
Z = Z.reshape(xx.shape).ravel()
xx = xx.ravel()
yy = yy.ravel()

# %%
from matplotlib import cm
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_xlabel('Tax')
ax.set_ylabel('PTRATIO')
ax.set_zlabel('PRICE')
surf = ax.plot_trisurf(xx, yy, Z , cmap=cm.jet, linewidth=0.1)
fig.colorbar(surf, shrink=0.5, aspect=10)    
plt.show()

# %%
# Out:
# 11.6
